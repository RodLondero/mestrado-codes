# %% [markdown]
# # Propriedades do ar

# %% [markdown]
#    Dados baseados no artigo:
# > A. Gleizes, Y. Cressault, and P. Teulet, “Mixing rules for thermal plasma properties in mixtures of argon, air and metallic vapours,” Plasma Sources Sci. Technol., vol. 19, no. 5, p. 055013, Oct. 2010, doi: 10.1088/0963-0252/19/5/055013.

# %% [markdown]
# ## Importações
# Seção onde são carregados os pacotes utilizados para calcular e plotar as propriedades do ar

# %%
from src.plots import *

save_fig = {
    'salvar': True, 
    'local': 'img/',
    'tipo': '.pdf'
}

# %% [markdown]
# ## Funções
# - **Plot Densidade**

# %%
plotDensity(save_fig)

# %% [markdown]
# - **Plot Calor Específico**

# %%
plotSpecificHeat(save_fig)

# %% [markdown]
# - **Plot Viscosidade**

# %%
plotViscosity(save_fig)

# %% [markdown]
# - **Plot Condutividade Térmica**

# %%
plotThermalCondutivity(save_fig)

# %% [markdown]
# - **Plot Condutividade Elétrica**
# > Essa propriedade não está sendo usada explicitamente, pois a biblioteca da Ansys converte essa informação em Difusão

# %%
plotElectricalCondutivity(save_fig)
